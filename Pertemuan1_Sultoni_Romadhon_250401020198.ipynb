# %% [markdown]
# <a href="https://colab.research.google.com/github/Sultoniromadhon/data-science-2026/blob/main/Pertemuan1_Sultoni_Romadhon_250401020198.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Nama : SULTONI ROMADHON
# * NIM : 250401020198
# * Kelas : IF403
# * Prodi : Informatika PJJ S1

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# SEL 2: Variabel dan tipe data dasar
nama = "Fulan" # String
angkatan = 2023 # Integer
ipk = 3.55 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    # Indentasi harus konsisten
    print(f" {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    # Pastikan tidak ada teks tambahan di luar string return
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Sultoni Romadhon", "Informatika", 2023)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Fulan
# Angkatan: 2023
# IPK : 3.55
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
# Hai! Saya Sultoni Romadhon dari Informatika, angkatan 2023.

# %% [markdown]
# Kesimpulan
#
# Pada pertemuan ini saya belajar dasar-dasar Python, seperti menampilkan output, menggunakan variabel, list, perulangan, dan fungsi. Temuan utama yang saya dapatkan adalah Python memiliki sintaks yang sederhana dan mudah dipahami untuk pemula. Keterbatasan saya saat ini adalah masih perlu lebih banyak latihan agar lebih memahami penggunaan Python dalam analisis data.
